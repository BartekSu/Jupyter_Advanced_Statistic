# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style('darkgrid')

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('ADANIPORTS.csv')
df.head()
# Out:
#          Date      Symbol Series  Prev Close    Open     High    Low   Last  \
# 0  2007-11-27  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.0  959.0
# 1  2007-11-28  MUNDRAPORT     EQ      962.90  984.00   990.00  874.0  885.0
# 2  2007-11-29  MUNDRAPORT     EQ      893.90  909.00   914.75  841.0  887.0
# 3  2007-11-30  MUNDRAPORT     EQ      884.20  890.00   958.00  890.0  929.0
# 4  2007-12-03  MUNDRAPORT     EQ      921.55  939.75   995.00  922.0  980.0
#
#     Close    VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# 0  962.90  984.72  27294366  2.687719e+15     NaN             9859619
# 1  893.90  941.38   4581338  4.312765e+14     NaN             1453278
# 2  884.20  888.09   5124121  4.550658e+14     NaN             1069678
# 3  921.55  929.17   4609762  4.283257e+14     NaN             1260913
# 4  969.30  965.65   2977470  2.875200e+14     NaN              816123
#
#    %Deliverble
# 0       0.3612
# 1       0.3172
# 2       0.2088
# 3       0.2735
# ...

# %%
df.shape
# Out:
# (3091, 15)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index(['Date','Symbol','Series'], inplace=True)

# %%
df.head()
# Out:
#                               Prev Close    Open     High    Low   Last  \
# Date       Symbol     Series
# 2007-11-27 MUNDRAPORT EQ          440.00  770.00  1050.00  770.0  959.0
# 2007-11-28 MUNDRAPORT EQ          962.90  984.00   990.00  874.0  885.0
# 2007-11-29 MUNDRAPORT EQ          893.90  909.00   914.75  841.0  887.0
# 2007-11-30 MUNDRAPORT EQ          884.20  890.00   958.00  890.0  929.0
# 2007-12-03 MUNDRAPORT EQ          921.55  939.75   995.00  922.0  980.0
#
#                                Close    VWAP    Volume      Turnover  Trades  \
# Date       Symbol     Series
# 2007-11-27 MUNDRAPORT EQ      962.90  984.72  27294366  2.687719e+15     NaN
# 2007-11-28 MUNDRAPORT EQ      893.90  941.38   4581338  4.312765e+14     NaN
# 2007-11-29 MUNDRAPORT EQ      884.20  888.09   5124121  4.550658e+14     NaN
# 2007-11-30 MUNDRAPORT EQ      921.55  929.17   4609762  4.283257e+14     NaN
# 2007-12-03 MUNDRAPORT EQ      969.30  965.65   2977470  2.875200e+14     NaN
#
# ...

# %%
# Check the distribution of skewness using ploot
for col in df.columns:
    sns.distplot(df[col])
    plt.show()

# %%
df.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  3091.000000  3091.000000  3091.000000  3091.000000  3091.000000
# mean    335.256001   335.812148   342.509609   328.726092   335.269994
# std     192.730346   193.364910   198.364675   188.416977   192.894286
# min     108.000000   108.000000   110.450000   105.650000   108.000000
# 25%     158.200000   159.250000   161.900000   155.600000   158.250000
# 50%     314.700000   315.300000   320.850000   309.250000   314.500000
# 75%     395.700000   396.000000   402.000000   388.575000   395.375000
# max    1307.450000  1310.250000  1324.000000  1270.000000  1308.000000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  3091.000000  3091.000000  3.091000e+03  3.091000e+03    2225.000000
# mean    335.218408   335.884549  2.491000e+06  7.562681e+13   38115.349663
# std     192.721241   193.579687  2.700413e+06  9.780847e+13   26240.865900
# ...

# %%
df = pd.read_csv('ADANIPORTS.csv')
df['Date'] = pd.to_datetime(df['Date'])
df.set_index(['Date'], inplace=True)

# %%
wdf = df.resample('Y').mean()
#W -weekly
#M- Mounthly
#Y - Yearly

# %%
wdf.head()
# Out:
#              Prev Close         Open         High          Low         Last  \
# Date
# 2007-12-31  1036.673913  1062.082609  1111.015217  1031.523913  1076.465217
# 2008-12-31   596.002439   597.078862   615.275203   575.508333   592.235772
# 2009-12-31   487.376749   489.420576   501.961728   477.934979   488.501852
# 2010-12-31   561.095833   558.971032   568.918651   550.137103   559.476587
# 2011-12-31   144.781579   144.902632   147.863158   141.731579   144.679555
#
#                   Close         VWAP        Volume      Turnover  \
# Date
# 2007-12-31  1072.708696  1078.949565  3.195464e+06  3.250962e+14
# 2008-12-31   592.167073   595.471016  5.058378e+05  3.259794e+13
# 2009-12-31   488.315638   490.940370  4.270371e+05  2.028325e+13
# 2010-12-31   559.471230   560.167460  6.588060e+05  2.883658e+13
# 2011-12-31   144.684413   144.845142  1.398155e+06  2.028919e+13
#
#                   Trades  Deliverable Volume  %Deliverble
# Date
# ...

# %%
wdf.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count    14.000000    14.000000    14.000000    14.000000    14.000000
# mean    380.462569   382.578656   391.990294   373.985711   383.047878
# std     239.552184   244.872886   256.253407   237.431000   247.691875
# min     126.971713   127.110558   129.536255   124.545418   126.957171
# 25%     234.320497   234.921705   239.486611   230.157812   234.861230
# 50%     342.136241   342.153996   347.302413   336.383213   342.325221
# 75%     460.636490   462.289208   472.852980   452.205061   461.413787
# max    1036.673913  1062.082609  1111.015217  1031.523913  1076.465217
#
#              Close         VWAP        Volume      Turnover        Trades  \
# count    14.000000    14.000000  1.400000e+01  1.400000e+01     10.000000
# mean    382.748165   383.731552  2.632717e+06  9.479136e+13  37776.461087
# std     246.878113   248.520825  1.543454e+06  8.334311e+13  15085.209416
# ...

# %%
### Inferences from the describe function of yerly analisys

# %%
plt.figure(figsize=(6,3), dpi = 100)
plt.tick_params(axis = 'x', rotation = 45)
plt.title('Analysis of annual results')
#purple','#CCFFCC',(0.2,0.2,0.4)---> 3 ways to show color
colors = ['pink', 'yellow', 'black', 'blue', '#99CCFF','red','yellow','green', 'cyan', 'orange', 'darkgreen', 'purple','#CCFFCC',(0.2,0.2,0.4)]
plt.bar(x= wdf.index, height = wdf.High,color = colors, edgecolor = ['black'],width=100)
plt.show()
