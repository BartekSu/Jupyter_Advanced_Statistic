# %%
import numpy as np

# %%
data1 = np.random.chisquare(df = 1 , size = 1000)
data2 = np.random.chisquare(df = 2 , size = 1000)
data3 = np.random.chisquare(df = 3 , size = 1000)
print(data1[:10])
# Out:
# [0.65275794 5.99314909 0.43200688 0.01240566 0.35024938 0.15228059
#  1.58054421 0.8560471  0.14357087 6.01277018]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#CHANGES IN SEABORN LIBRARY!
#sns.distplot(data1, hist = False, label = 'Stopnie swobody = 1')
sns.kdeplot(data1, label ='Degrees of freedom = 1')
#sns.distplot(data2, hist = False, label = 'Stopnie swobody = 2')
sns.kdeplot(data2, label ='Degrees of freedom = 2')
#sns.distplot(data3, hist = False, label = 'Stopnie swobody = 3')
sns.kdeplot(data3, label ='Degrees of freedom = 3')
plt.legend()

# %%
from scipy.stats import chi2_contingency

# %%
data = [[10,20,30],[6,9,17]]

# %%
stat,p_value,dof,chi_array = chi2_contingency(data)
print('stat =',stat)
print('p_value =',p_value)
print('dof =',dof)
print('\nchi_array =',chi_array)
# Out:
# stat = 0.27157465150403504
# p_value = 0.873028283380073
# dof = 2
#
# chi_array = [[10.43478261 18.91304348 30.65217391]
#  [ 5.56521739 10.08695652 16.34782609]]

# %%
p_value
# Out:
# 0.873028283380073

# %%
data1 = [[10,20,30],[9,1,8]]
stat,p_value,dof,chi_array = chi2_contingency(data1)
p_value
# Out:
# 0.005595003173072841
